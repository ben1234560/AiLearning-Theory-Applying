# %% [markdown]
# ### Permutation Importance

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv('data/FIFA 2018 Statistics.csv')  # 足球赛事数据集
data.head()
# Out:
#          Date          Team      Opponent  Goal Scored  Ball Possession %  \
# 0  14-06-2018        Russia  Saudi Arabia            5                 40
# 1  14-06-2018  Saudi Arabia        Russia            0                 60
# 2  15-06-2018         Egypt       Uruguay            0                 43
# 3  15-06-2018       Uruguay         Egypt            1                 57
# 4  15-06-2018       Morocco          Iran            0                 64
#
#    Attempts  On-Target  Off-Target  Blocked  Corners  ...  Yellow Card  \
# 0        13          7           3        3        6  ...            0
# 1         6          0           3        3        2  ...            0
# 2         8          3           3        2        0  ...            2
# 3        14          4           6        4        5  ...            0
# 4        13          3           6        4        5  ...            1
#
#    Yellow & Red  Red  Man of the Match  1st Goal        Round  PSO  \
# ...

# %% [markdown]
# 怎么知道哪些特征影响多大
#
# 破坏特征：比如把Goal Scored上下的顺序打乱，其它不变，然后比较破坏前和后的区别
#
# 如果前 ≈ 后，说明这个特征对结果没影响
# 如果后 ＜ 前，说明这个特征对结果影响起正作用
# 如果后 ＞ 前，说明这个特征对结果影响起负作用（一般不会出现）

# %%
y = (data['Man of the Match'] == 'Yes')  # 转换标签
y[:5]
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Man of the Match, dtype: bool

# %%
feature_names = [i for i in data.columns if data[i].dtype in [np.int64]]
X = data[feature_names]
X.head()
# Out:
#    Goal Scored  Ball Possession %  Attempts  On-Target  Off-Target  Blocked  \
# 0            5                 40        13          7           3        3
# 1            0                 60         6          0           3        3
# 2            0                 43         8          3           3        2
# 3            1                 57        14          4           6        4
# 4            0                 64        13          3           6        4
#
#    Corners  Offsides  Free Kicks  Saves  Pass Accuracy %  Passes  \
# 0        6         3          11      0               78     306
# 1        2         1          25      2               86     511
# 2        0         1           7      3               78     395
# 3        5         1          13      3               86     589
# 4        5         0          14      2               86     433
#
#    Distance Covered (Kms)  Fouls Committed  Yellow Card  Yellow & Red  Red  \
# ...

# %%
train_X, val_X,train_y,val_y = train_test_split(X, y,random_state=1)
my_model = RandomForestClassifier(random_state=0).fit(train_X,train_y)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
import eli5 # pip install eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(my_model,random_state=1).fit(val_X, val_y)

eli5.show_weights(perm, feature_names=val_X.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0750
#
#                     &plusmn; 0.1159
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Goal Scored
#             </td>
# ...

# %% [markdown]
# ### Partial Dependence Plots
#
# 特征重要性展示了每个特征发挥的作用情况，partial dependence plots 可以展示一个特征怎么影响预测结果
#
# 模型建立完成后进行使用，概述如下：
# <ul>
#     <li>首先选中一个样本数据，此时想观察Ball Possession列对结果的影响。
#     <li>保证其它特征列不变，改变当前观察列的值，例如悬着40%，50%，60%分别进行预测，得到各自的结果。
#     <li>对比结果就能知道当前列（Ball Possession）对结果的影响情况。

# %%
import matplotlib.pyplot as plt
from pdpbox import pdp, get_dataset, info_plots  # pip install pdpbox
pdp_goals = pdp.pdp_isolate(model=my_model,
                            dataset=val_X, 
                            model_features=feature_names,
                            feature='Goal Scored')  # 观察的特征

pdp.pdp_plot(pdp_goals, 'Goal Scored')
plt.show()

# %% [markdown]
# y轴表示预测结果的变化对比于基本模型，由于在观察时不可能只看一个样本数据，肯定要选择多个样本数据，蓝色区域表示的是置信度

# %%
feature_to_plot = 'Distance Covered (Kms)'

rf_model = RandomForestClassifier(random_state=0).fit(train_X, train_y)

pdp_dist = pdp.pdp_isolate(model=rf_model, dataset=val_X,
                          model_features=feature_names,
                          feature=feature_to_plot)

pdp.pdp_plot(pdp_dist,feature_to_plot)
plt.show()

# %% [markdown]
# ### 双特征观察
# 需要先改源码：将Anaconda3\Lib\site-packages\pdpbox 下 pdp_plot_utils.py文件中contour_label_fontsize=fontsize改成fontsize=fontsize

# %%
features_to_plot = ['Goal Scored', 'Distance Covered (Kms)']
inter1 = pdp.pdp_interact(model=rf_model, dataset=val_X,
                         model_features=feature_names,
                         features=features_to_plot)

pdp.pdp_interact_plot(pdp_interact_out=inter1, feature_names=features_to_plot,
                     plot_type='contour')
plt.show()

# %% [markdown]
# 可以观察到，在跑动距离为100的情况下，进球数量越多，是不是意味着赢得可能性越大

# %% [markdown]
# ### SHAP Values
# 可以直观的展示每一个特征对结果走势的影响

# %%
row_to_show = 5
data_for_prediction = val_X.iloc[row_to_show]
data_for_prediction_array = data_for_prediction.values.reshape(1, -1)

my_model.predict_proba(data_for_prediction_array)  # 能赢的概率为70%
# Out:
# array([[0.3, 0.7]])

# %% [markdown]
# 导入shap工具包可能出现问题，在Anaconda3\Lib\site-packages\numpy\lib\arraypad.py中添加下面两个函数到_as_pairs和_as_pairs之间（956行）保存，重新加载即可，utf-8格式

# %% [markdown]
# def _normalize_shape(ndarray, shape, cast_to_int=True):
#     ndims = ndarray.ndim
#
#     if shape is None:
#         return ((None, None),) * ndims
#
#     shape_arr = np.asarray(shape)
#
#     try:
#             shape_arr = np.broadcast_to(shape_arr, (ndims, 2))
#     except ValueError:
#         fmt = "Unable to create correctly shaped tuple from %s"
#         raise ValueError(fmt % (shape,))
#
#     if cast_to_int is True:
#         shape_arr = np.round(shape_arr).astype(int)
#
#     return tuple(tuple(axis) for axis in shape_arr.tolist())
#
#
# def _validate_lengths(narray, number_elements):
#     normshp = _normalize_shape(narray, number_elements)
#     for i in normshp:
#         chk = [1 if x is None else x for x in i]
#         chk = [1 if x >= 0 else -1 for x in chk]
#         if (chk[0] > 0) or (chk[1] < 0):
#             fmt = "%s cannot contain negative values."
#             raise ValueError(fmt % (number_elements,))
#     return normshp

# %%
import shap  # pip install shap

#实例化
explainer = shap.TreeExplainer(my_model)

#计算
shap_values = explainer.shap_values(data_for_prediction)

# %% [markdown]
# 返回的SHAP values中包括了negative和positive两种情况，通常选择一种（positive）即可

# %%
shap.initjs()
# shap_values[1]指定为positive，0为negative
shap.force_plot(explainer.expected_value[1], shap_values[1], data_for_prediction)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# 0.70表示赢得概率，红色表示能够朝1得方向发展得，蓝色表示能够朝0得方向发展的；
#
# 即红色的值越大越容易赢，蓝色值越大越容易输；
#
# 多个深红色小块之间，区域越大，表示影响结果的能力越大。蓝色同理。如图中绿框区域
# <img src="assets/20201212155754.png" width="50%">
#
# 这里的结果是选了样本，不够全面

# %% [markdown]
# ### Summary Plots

# %%
explainer = shap.TreeExplainer(my_model)

shap_values = explainer.shap_values(val_X)  # 选择全部样本

shap.summary_plot(shap_values[1], val_X)

# %% [markdown]
# Y轴是特征，X轴是正负，正的表示特征对结果起促进作用，负的表示特征对结果起抑制作用。右边Y轴表示越高，对结果影响越大。
#
# 如上图中：
#     Goal Scored 左边区域的蓝色：进球越少就越抑制赢球这一结果。
#     Goal Scored 右边区域的红色：进球越多就越促进赢球这一结果。
