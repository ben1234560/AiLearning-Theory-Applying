# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# 使用随机数填充矩阵
matrix = np.random.rand(4, 16, 768)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 设置随机种子以便结果可复现
np.random.seed(0)

# 生成一个[16,768]维度的随机矩阵，值在[-1,1]之间
matrix = np.random.uniform(low=-1.0, high=1.0, size=(16, 768))

# 使用matplotlib可视化这个矩阵
plt.figure(figsize=(20, 5))  # 设置图像大小
plt.imshow(matrix, cmap='coolwarm', aspect='auto')  # 使用coolwarm色图，自动调整长宽比
plt.colorbar()  # 显示颜色条
plt.title('d_model = 512')  # 设置图像标题
plt.xlabel('')  # 设置x轴标签
plt.ylabel('ctx_length = 16')  # 设置y轴标签
plt.show()

# %%
import numpy as np

# 假设你已经有了一个名为matrix的NumPy数组
# matrix = np.random.uniform(low=-1.0, high=1.0, size=(16, 768))

# 保存为.npy格式
np.save('matrix.npy', matrix)

# %%
import numpy as np

np.random.seed(0)
matrix_Q_K = np.random.rand(3, 3)
matrix_V = np.random.rand(3, 6)
matrix_A = np.dot(matrix_A, matrix_B)

print("matrix_Q_K (3x3):")
print(matrix_Q_K)
print("\nMatrix_V (3x6):")
print(matrix_V)
print("\nmatrix_A (3x6):")
print(matrix_A)
# Out:
# matrix_Q_K (3x3):
# [[0.5488135  0.71518937 0.60276338]
#  [0.54488318 0.4236548  0.64589411]
#  [0.43758721 0.891773   0.96366276]]
#
# Matrix_V (3x6):
# [[0.38344152 0.79172504 0.52889492 0.56804456 0.92559664 0.07103606]
#  [0.0871293  0.0202184  0.83261985 0.77815675 0.87001215 0.97861834]
#  [0.79915856 0.46147936 0.78052918 0.11827443 0.63992102 0.14335329]]
#
# matrix_A (3x6):
# [[0.75445535 0.72713223 1.35621994 0.93957145 1.51592433 0.82529109]
#  [0.76201539 0.73803008 1.14506854 0.71558053 1.28624809 0.54589376]
#  [1.01560801 0.80918945 1.72611245 1.05648488 1.79755065 1.04193411]]

# %%
0.5488135*0.38344152 + 0.71518937*0.0871293 + 0.60276338*0.79915856
# Out:
# 0.7544553465935937

# %%
0.54488318*0.38344152 + 0.4236548*0.0871293 + 0.64589411*0.79915856
# Out:
# 0.7620153877873552

# %%
print("matrix_Q_K (3x3):")
print(matrix_Q_K)
print("\nMatrix_V (3x6):")
print(matrix_V)
print("\nmatrix_A (3x6):")
print(matrix_A)
# Out:
# matrix_Q_K (3x3):
# [[0.5488135  0.71518937 0.60276338]
#  [0.54488318 0.4236548  0.64589411]
#  [0.43758721 0.891773   0.96366276]]
#
# Matrix_V (3x6):
# [[0.38344152 0.79172504 0.52889492 0.56804456 0.92559664 0.07103606]
#  [0.0871293  0.0202184  0.83261985 0.77815675 0.87001215 0.97861834]
#  [0.79915856 0.46147936 0.78052918 0.11827443 0.63992102 0.14335329]]
#
# matrix_A (3x6):
# [[0.75445535 0.72713223 1.35621994 0.93957145 1.51592433 0.82529109]
#  [0.76201539 0.73803008 1.14506854 0.71558053 1.28624809 0.54589376]
#  [1.01560801 0.80918945 1.72611245 1.05648488 1.79755065 1.04193411]]

# %%
0.5488135*0.79172504 + 0.71518937*0.0202184 + 0.60276338*0.46147936
# Out:
# 0.7271322338322848

# %%
0.5488135*0.52889492 + 0.71518937*0.83261985 + 0.60276338*0.78052918
# Out:
# 1.356219944873843

# %%
from transformers import GPT2Config

# 创建一个GPT-2配置实例，这里以124M版本为例
config = GPT2Config.from_pretrained('gpt2')

# 打印位置编码的维度
print(config.n_embd)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# 768
